# %%
# Instalar el driver para Pymongo
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.14.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pymongo) (2.7.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Importamos las clases MongoClient y ServApi
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd

# %%
# Definir la URI de cone
uri = 'mongodb+srv://cesarcp:1234@default.pnri1kk.mongodb.net/?retryWrites=true&w=majority&appName=default'

# Nueva instancia de la cliente mongo
client = MongoClient(uri, server_api=ServerApi('1'))

try:
    # Enviar un comando ping al servidor
    client.admin.command('ping')
    # Imprimir el mensaje
    print('Ping exitoso')
except Exception as e:
    print(e)
# Out:
# Ping exitoso

# %%
dbname = client['sample_airbnb']

collection_name = dbname['listingsAndReviews']

# realizar una consulta para extraer todos los documentos
listingsAndReviews_cursor = collection_name.find({})

listingsAndReviews_df = pd.DataFrame(listingsAndReviews_cursor)

# %%
listingsAndReviews_df.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1   1001265   https://www.airbnb.com/rooms/1001265
# 2  10030955  https://www.airbnb.com/rooms/10030955
# 3  10057447  https://www.airbnb.com/rooms/10057447
# 4  10059872  https://www.airbnb.com/rooms/10059872
#
#                                  name  \
# 0             Ribeira Charming Duplex
# 1    Ocean View Waikiki Marina w/prkg
# 2         Apt Linda Vista Lagoa - Rio
# 3      Modern Spacious 1 Bedroom Loft
# 4  Soho Cozy, Spacious and Convenient
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  A short distance from Honolulu's billion dolla...
# 2  Quarto com vista para a Lagoa Rodrigo de Freit...
# 3  Prime location, amazing lighting and no annoyi...
# 4  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1  Great studio located on Ala Moana across the s...
# 2
# 3  Lot's of plants and lights.  Really great mode...
# 4
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  A short distance from Honolulu's billion dolla...
# 2  Quarto com vista para a Lagoa Rodrigo de Freit...
# 3  Prime location, amazing lighting and no annoyi...
# 4  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1             You can breath ocean as well as aloha.
# 2
# 3
# 4
#
#                                                notes  \
# 0  Lose yourself in the narrow streets and stairc...
# 1
# 2
# 3
# 4
#
#                                              transit  \
# 0  Transport: • Metro station and S. Bento railwa...
# 1  Honolulu does have a very good air conditioned...
# 2
# 3
# 4
#
#                                               access  ... guests_included  \
# 0  We are always available to help guests. The ho...  ...               6
# 1                           Pool, hot tub and tennis  ...               1
# 2                                                     ...               1
# 3                                                     ...               1
# 4                                                     ...               1
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '51399391', 'host_url': 'https://w...
# 1  {'host_id': '5448114', 'host_url': 'https://ww...
# 2  {'host_id': '51496939', 'host_url': 'https://w...
# 3  {'host_id': '51612949', 'host_url': 'https://w...
# 4  {'host_id': '51624384', 'host_url': 'https://w...
#
#                                              address  \
# 0  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 1  {'street': 'Honolulu, HI, United States', 'sub...
# 2  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3  {'street': 'Montréal, Québec, Canada', 'suburb...
# 4  {'street': 'Hong Kong, Hong Kong Island, Hong ...
#
#                                         availability  \
# 0  {'availability_30': 28, 'availability_60': 47,...
# 1  {'availability_30': 16, 'availability_60': 46,...
# 2  {'availability_30': 28, 'availability_60': 58,...
# 3  {'availability_30': 0, 'availability_60': 0, '...
# 4  {'availability_30': 0, 'availability_60': 0, '...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 9, 'review_scores_c...
# 1  {'review_scores_accuracy': 9, 'review_scores_c...
# 2                                                 {}
# 3                                                 {}
# 4  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                              reviews weekly_price  \
# 0  [{'_id': '58663741', 'date': 2016-01-03 05:00:...          NaN
# 1  [{'_id': '4765259', 'date': 2013-05-24 04:00:0...       650.00
# 2                                                 []          NaN
# 3                                                 []          NaN
# 4  [{'_id': '56904633', 'date': 2015-12-19 05:00:...      5000.00
#
#   monthly_price reviews_per_month
# 0           NaN               NaN
# 1       2150.00               NaN
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN
#
# [5 rows x 42 columns]
